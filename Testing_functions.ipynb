# %%
import pandas as pd
from fuzzywuzzy import process

df = pd.read_csv(r'C:\Users\liamp\OneDrive\Desktop\Liams_path_to_Data_science\Football_api_project\Output_files\df_championship_39_2021_full.csv')
        
print(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 780 non-null    int64
#  1   Name               780 non-null    object
#  2   Age                777 non-null    float64
#  3   Height             673 non-null    object
#  4   Weight             616 non-null    object
#  5   Nationality        780 non-null    object
#  6   Injured            780 non-null    bool
#  7   Team               780 non-null    object
#  8   Position           780 non-null    object
#  9   Games              778 non-null    float64
#  10  Minutes            778 non-null    float64
#  11  Accuracy_Passes    528 non-null    float64
#  12  Key_Passes         434 non-null    float64
#  13  Total_Passes       531 non-null    float64
#  14  Shots_On           381 non-null    float64
#  15  Shots_Total        431 non-null    float64
#  16  Dribbles_Attempts  447 non-null    float64
#  17  Dribbles_Past      0 non-null      float64
#  18  Dribbles_Success   424 non-null    float64
#  19  Fouls_Drawn        464 non-null    float64
#  20  Fouls_Committed    462 non-null    float64
#  21  Tackled_Block      361 non-null    float64
#  22  Tackled_Intercept  433 non-null    float64
#  23  Tackled_Total      466 non-null    float64
#  24  Duels_Won          509 non-null    float64
#  25  Duels_Total        519 non-null    float64
#  26  Goals_Assist       275 non-null    float64
#  27  Goals_Total        778 non-null    float64
#  28  Goals_Conceded     676 non-null    float64
#  29  Goals_Saves        42 non-null     float64
#  30  Photo              780 non-null    object
#  31  Logo_Team          780 non-null    object
#  32  Rating             524 non-null    float64
#  33  Yellow_Cards       778 non-null    float64
#  34  Red_Cards          778 non-null    float64
#  35  Yellow_Red_Cards   778 non-null    float64
#  36  Captain            780 non-null    bool
# dtypes: bool(2), float64(26), int64(1), object(8)
# memory usage: 214.9+ KB
# None
# c:\Users\liamp\AppData\Local\Programs\Python\Python311\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#       Id          Name   Age  Height Weight Nationality  Injured  \
# 0    159     H. Lloris  37.0  188 cm  82 kg      France    False
# 1    882  David de Gea  33.0  192 cm  76 kg       Spain    False
# 2  20619    I. Meslier  23.0  197 cm  74 kg      France    False
# 3  19298       M. Cash  26.0  185 cm  79 kg      Poland    False
# 4  18741      C. Coady  30.0  185 cm  80 kg     England    False
#
#                 Team    Position  Games  ...  Goals_Total  Goals_Conceded  \
# 0          Tottenham  Goalkeeper   38.0  ...          0.0            40.0
# 1  Manchester United  Goalkeeper   38.0  ...          0.0            57.0
# 2              Leeds  Goalkeeper   38.0  ...          0.0            79.0
# 3        Aston Villa    Defender   38.0  ...          4.0             0.0
# 4             Wolves    Defender   38.0  ...          4.0             0.0
#
#    Goals_Saves                                              Photo  \
# 0         98.0  https://media-1.api-sports.io/football/players...
# 1        128.0  https://media-2.api-sports.io/football/players...
# 2        143.0  https://media-3.api-sports.io/football/players...
# 3          NaN  https://media-1.api-sports.io/football/players...
# 4          NaN  https://media-1.api-sports.io/football/players...
#
#                                            Logo_Team    Rating  Yellow_Cards  \
# 0  https://media-1.api-sports.io/football/teams/4...  7.000000           2.0
# 1  https://media-3.api-sports.io/football/teams/3...  6.860526           0.0
# 2  https://media-2.api-sports.io/football/teams/6...  6.860526           2.0
# 3  https://media-1.api-sports.io/football/teams/6...  6.955263           8.0
# 4  https://media-3.api-sports.io/football/teams/3...  7.034210           5.0
#
#    Red_Cards  Yellow_Red_Cards  Captain
# 0        0.0               0.0    False
# 1        0.0               0.0    False
# 2        0.0               0.0    False
# 3        0.0               0.0    False
# 4        0.0               0.0    False
#
# [5 rows x 37 columns]

# %%
correct_row = df[df["Name"] == 'H. Lloris']
correct_row['Team']
# Out:
# 0    Tottenham
# Name: Team, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 780 non-null    int64
#  1   Name               780 non-null    object
#  2   Age                777 non-null    float64
#  3   Height             673 non-null    object
#  4   Weight             616 non-null    object
#  5   Nationality        780 non-null    object
#  6   Injured            780 non-null    bool
#  7   Team               780 non-null    object
#  8   Position           780 non-null    object
#  9   Games              778 non-null    float64
#  10  Minutes            778 non-null    float64
#  11  Accuracy_Passes    528 non-null    float64
#  12  Key_Passes         434 non-null    float64
#  13  Total_Passes       531 non-null    float64
#  14  Shots_On           381 non-null    float64
#  15  Shots_Total        431 non-null    float64
#  16  Dribbles_Attempts  447 non-null    float64
#  17  Dribbles_Past      0 non-null      float64
#  18  Dribbles_Success   424 non-null    float64
#  19  Fouls_Drawn        464 non-null    float64
#  20  Fouls_Committed    462 non-null    float64
#  21  Tackled_Block      361 non-null    float64
#  22  Tackled_Intercept  433 non-null    float64
#  23  Tackled_Total      466 non-null    float64
#  24  Duels_Won          509 non-null    float64
#  25  Duels_Total        519 non-null    float64
#  26  Goals_Assist       275 non-null    float64
#  27  Goals_Total        778 non-null    float64
#  28  Goals_Conceded     676 non-null    float64
#  29  Goals_Saves        42 non-null     float64
#  30  Photo              780 non-null    object
#  31  Logo_Team          780 non-null    object
#  32  Rating             524 non-null    float64
#  33  Yellow_Cards       778 non-null    float64
#  34  Red_Cards          778 non-null    float64
#  35  Yellow_Red_Cards   778 non-null    float64
#  36  Captain            780 non-null    bool
# dtypes: bool(2), float64(26), int64(1), object(8)
# memory usage: 214.9+ KB

# %%
gk = df[df['Position'] == 'Goalkeeper'].Name
gk
# Out:
# 0           H. Lloris
# 1        David de Gea
# 2          I. Meslier
# 5        Ł. Fabiański
# 6      Robert Sánchez
#             ...
# 748      L. Bergström
# 750         T. McGill
# 767           K. Hein
# 770       V. Sinisalo
# 774      R. Rúnarsson
# Name: Name, Length: 88, dtype: object

# %%
import pandas as pd
from fuzzywuzzy import process

# Output the top matches and their scores
# for match, score in [(x[0], x[1]) for x in top_matches]:
#     print(f"Match: {match}, Score: {score}")

def choose_player(df: pd.DataFrame,user_input: str) -> pd.DataFrame:
    """This function will be used to find the player that the user inputs in the database.
    It uses fuzzy matching so that different inputs can be accepted. 
    The output of this should be the row of the dataframe that is applicable so that it can
    be stored as a player object and used in later analysis. 

    Args:
        df (pd.DataFrame): The player dataframe from the api to compare to the given player name
        user_input (str): The player that the user wants to add into his team.
    Returns:
        df: The output which is applicable to the player chosen by the user
    """
    top_matches = process.extract(user_input, df['Name'], limit=3)
    
    
    best_match_row = df[df["Name"] == top_matches[0][0]]
    second_best_match = df[df["Name"] == top_matches[1][0]]
    third_best_match = df[df["Name"] == top_matches[2][0]]
    selected_player = None
    
    while True:
        correct_player = input(f'Do you mean: {top_matches[0][0]}?. He plays for {best_match_row["Team"].iloc[0]} right? Please use Y/N or E to exit').upper()
        if correct_player in ['Y', 'N']:
            selected_player = best_match_row
            break
        elif correct_player == 'E':
            print("Exiting the process.")
            break
        else:
            print("Invalid input. Please enter 'Y' or 'N'.")

    if correct_player == 'N':
        while True:
            second_try = input(f'My apologies,do you mean: {top_matches[1][0]}?. He plays for {second_best_match["Team"].iloc[0]} right? Please use Y/N or E to exit').upper()
            if second_try in ['Y', 'N']:
                selected_player = second_best_match
                break
            elif correct_player == 'E':
                print("Exiting the process.")
                break
            else:
                print("Invalid input. Please enter 'Y' or 'N'.")
        if second_try == 'N':
            while True:
                last_try = input(f'My apologies,lets try one more time. Do you mean: {top_matches[2][0]}?. He plays for {third_best_match["Team"].iloc[0]} right? Please use Y/N or E to exit').upper()
                if second_try in ['Y', 'N']:
                    selected_player = third_best_match
                    break
                elif correct_player == 'E':
                    print("Exiting the process.")
                    break
                else:
                    print("Invalid input. Please enter 'Y' or 'N'.")
            if last_try == 'N':
                print(f'Please try again, here is a list of all names for reference: {df[df["Position"] == "Goalkeeper"].Name}')
            else:
                print(f'Excellent! You have successfully added {top_matches[2][0]} to your side!')
        else:
            print(f'You have successfully added {top_matches[1][0]} to your side!')    
    else:
        print(f'You have successfully added {top_matches[0][0]} to your side!')
        
    # Have to convert the pandas df with 1 row into a Series
    selected_player = selected_player.iloc[0]   
    return selected_player

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\liamp\OneDrive\Desktop\Liams_path_to_Data_science\Football_api_project\Output_files\df_championship_39_2021_full.csv')
# user_input = input("Enter a name: ")
user_input = 'H.Lloris'

output = choose_player(df, user_input)
# Out:
# You have successfully added H. Lloris to your side!

# %%
display(output)
# Out:
# Id                                                                 159
# Name                                                         H. Lloris
# Age                                                               37.0
# Height                                                          188 cm
# Weight                                                           82 kg
# Nationality                                                     France
# Injured                                                          False
# Team                                                         Tottenham
# Position                                                    Goalkeeper
# Games                                                             38.0
# Minutes                                                         3420.0
# Accuracy_Passes                                                   16.0
# Key_Passes                                                         2.0
# Total_Passes                                                     793.0
# Shots_On                                                           NaN
# Shots_Total                                                        NaN
# Dribbles_Attempts                                                  NaN
# Dribbles_Past                                                      NaN
# Dribbles_Success                                                   NaN
# Fouls_Drawn                                                        2.0
# Fouls_Committed                                                    NaN
# Tackled_Block                                                      NaN
# Tackled_Intercept                                                  1.0
# Tackled_Total                                                      1.0
# Duels_Won                                                         16.0
# Duels_Total                                                       19.0
# Goals_Assist                                                       NaN
# Goals_Total                                                        0.0
# Goals_Conceded                                                    40.0
# Goals_Saves                                                       98.0
# Photo                https://media-1.api-sports.io/football/players...
# Logo_Team            https://media-1.api-sports.io/football/teams/4...
# Rating                                                             7.0
# Yellow_Cards                                                       2.0
# Red_Cards                                                          0.0
# Yellow_Red_Cards                                                   0.0
# Captain                                                          False
# Name: 0, dtype: object

# %%
import pandas as pd
from utils.football_class import FootballPlayer 

player = FootballPlayer(output["Id"], output["Name"], output["Age"],output["Team"], output["Position"])

print(player)
# Out:
# Name: H. Lloris, Age: 37.0, Team: Tottenham, Position: Goalkeeper

# %%
def picking_starting_11(df: pd.DataFrame):
    GK_name = input("Hello, Who would you like to select as your starting GK? Please give first and last names")
    Search_dataframe = df[df["Name"] = GK_name]
        
    
    
    
    input()
